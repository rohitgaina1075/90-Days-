# %%
# ✅ 1. What is OOP?
# ✅ Answer: Object-Oriented Programming

# Explanation: OOP is a programming paradigm that organizes code into classes and objects.

# %%
# ✅ 2. What is a Class?
# ✅ Answer: A Blueprint for Creating Objects

# %%
# ✅ 3. What is an Object?
# ✅ Answer: An Instance of a Class

# %%
# ✅ 4. Which keyword is used to create a class?
# ✅ Answer: class

# %%
# ✅ 5. Which special method is the constructor?
# ✅ Answer: __init__()

# %%
class Student:
    def __init__(self):
        print("Constructor Called")

# %%
# ✅ 6. What does self represent?
# ✅ Answer: Current Object

# %%
class Student:
    def show(self):
        print("Hello")

# %%
# ✅ 7. Which variable belongs to each object?
# ✅ Answer: Instance Variable

# %%
# self.name = "Rohit"

# %%
# ✅ 8. Which variable is shared by all objects?
# ✅ Answer: Class Variable

# %%
class Student:
    school = "ABC School"

# %%
# ✅ 9. Which decorator creates a class method?
# ✅ Answer: @classmethod

# %%
# ✅ 10. Which decorator creates a static method?
# ✅ Answer: @staticmethod

# %%
# ✅ 11. Which keyword is used for inheritance?
# ✅ Answer: Parent class name inside parentheses

# %%
# ✅ 12. What is Inheritance?
# ✅ Answer: Reusing Parent Class Features

# %%
# ✅ 13. Which function calls the parent constructor?
# ✅ Answer: super()

# %%
# super().__init__()

# %%
# ✅ 14. What is Method Overriding?
# ✅ Answer: Redefining a Parent Method in a Child Class

# %%
# ✅ 15. Which pillar of OOP hides data?
# ✅ Answer: Encapsulation

# %%
# ✅ 16. Which pillar of OOP allows one class to acquire the properties of another?
# ✅ Answer: Inheritance

# Explanation: Inheritance lets a child class reuse the attributes and methods of a parent class.

# %%
# ✅ 17. Which pillar of OOP allows the same method name to have different behavior?
# ✅ Answer: Polymorphism

# %%
class Dog:
    def sound(self):
        print("Bark")

class Cat:
    def sound(self):
        print("Meow")

# %%
# ✅ 18. Which pillar hides implementation details?
# ✅ Answer: Abstraction

# %%
# ✅ 19. Which module is used to create abstract classes?
# ✅ Answer: abc

# %%
# ✅ 20. Which decorator creates an abstract method?
# ✅ Answer: @abstractmethod

# %%
# ✅ 21. Which function checks whether an object belongs to a class?
# ✅ Answer: isinstance()

# %%
# isinstance(student, Student)

# %%
# ✅ 22. Which function checks whether one class inherits from another?
# ✅ Answer: issubclass()

# %%
# issubclass(Dog, Animal)

# %%
# ✅ 23. Which magic method is called when an object is printed?
# ✅ Answer: __str__()

# %%
# ✅ 24. Which magic method overloads the + operator?
# ✅ Answer: __add__()

# %%
# ✅ 25. Which magic method compares two objects using ==?
# ✅ Answer: __eq__()

# %%
# ✅ 26. What is the output?
class A:
    pass

a = A()

print(isinstance(a, A))
# Out:
# True

# %%
# ✅ 27. What is the output?
class A:
    pass

class B(A):
    pass

print(issubclass(B, A))
# Out:
# True

# %%
# ✅ 28. Which method is automatically called when an object is created?
# ✅ Answer: __init__()

# %%
# ✅ 29. Which statement about static methods is correct?
# ✅ Answer: They don't receive self or cls.

# %%
# ✅ 30. Which OOP concept increases code reusability the most?
# ✅ Answer: Inheritance

# Explanation: Inheritance allows child classes to reuse the code of parent classes, reducing duplication.
