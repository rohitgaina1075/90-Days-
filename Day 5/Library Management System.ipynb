# %%
import os

class Library:

    File_Name = "books.txt"

    def add_book(self):

        title = input("Enter Book title:")
        author = input("Enter Book Author:")

        with open(self.File_Name,"a") as file:
            file.write(f"{title},{author},Avaulable\n")

        print("✅ Book Added Succefully!")

    def view_books(Self):

        if not os.path.exists(s)
