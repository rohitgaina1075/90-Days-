# %%
# ✅ 1. What is OOP?
# ✅ Answer: Object Oriented Programming

# %%
# ✅ 2. Which keyword is used to define a class?
# ✅ Answer: class

# %%
# ✅ 3. Which method is called automatically when an object is created?
# ✅ Answer: __init__()

# %%
# ✅ 4. What is self?
# ✅ Answer: Reference to the current object

# %%
# ✅ 5. Which of the following creates an object?
# ✅ Answer: Student()

# %%
# ✅ 6. Which variable belongs to every object separately?
# ✅ Answer: Instance Variable

# %%
# ✅ 7. Which variable is shared by all objects?
# ✅ Answer: Class Variable

# %%
# ✅ 8. What is Inheritance?
# ✅ Answer: Reusing code from another class

# %%
# ✅ 9. Which symbol is used for inheritance?
# ✅ Answer: ()

# %%
# ✅ 10. Which class is called the Parent Class?
# ✅ Answer: Base Class

# %%
# ✅ 11. Which class inherits from another class?
# ✅ Answer: Child Class

# %%
# ✅ 12. Which keyword calls the parent class constructor?
# ✅ Answer: super()

# %%
# ✅ 13. What is Method Overriding?
# ✅ Answer: Child class redefines the parent method

# %%
# ✅ 14. What is Polymorphism?
# ✅ Answer: One interface, many implementations

# %%
# ✅ 15. Which function checks whether an object belongs to a class?
# ✅ Answer: isinstance()

# %%
# ✅ 16. Which keyword makes a variable private in Python?
# ✅ Answer: __ (Double Underscore)

# %%
# ✅ 17. Which method is commonly used to access a private variable?
# ✅ Answer: Getter

# %%
# ✅ 18. Which decorator is used to create a static method?
# ✅ Answer: @staticmethod

# %%
# ✅ 19. Which decorator is used to create a class method?
# ✅ Answer: @classmethod

# %%
# ✅ 20. Which parameter is passed to a class method?
# ✅ Answer: cls

# %%
# ✅ 21. Which decorator is used to create a property?
# ✅ Answer: @property

# %%
# ✅ 22. Which module provides support for Abstract Base Classes?
# ✅ Answer: abc

# %%
# ✅ 23. Which decorator marks a method as abstract?
# ✅ Answer: @abstractmethod

# %%
# ✅ 24. Can an abstract class be instantiated directly?
# ✅ Answer: No

# %%
# ✅ 25. Which function returns the Method Resolution Order?
# ✅ Answer: mro()

# %%
# ✅ 26. Which special method defines the string representation of an object?
# ✅ Answer: __str__()
