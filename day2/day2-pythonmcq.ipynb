# %% [markdown]
# 1. What does len() return?  Answer:Number of elements ✅

# %%
# Explanation: len() returns the total number of items in a string, list, tuple, dictionary, etc.
print(len("Python"))
# Out:
# 6

# %% [markdown]
# 2. Which data type is mutable? Answer: List ✅
# Explanation: Lists can be modified after creation.

# %% [markdown]
# 3. Which data type is immutable? Answer: Tuple ✅

# %% [markdown]
# 4. Which keyword is used to create a function?  Answer: def ✅

# %% [markdown]
# 5. Output?

# %%
print(5//2) 
# Explanation: // performs floor division.
# Out:
# 2

# %% [markdown]
# 6. Output?

# %%
print(5%2)
# Out:
# 1

# %% [markdown]
# 7. Which loop is used when the number of iterations is known? Answer: for ✅

# %% [markdown]
# 8. Which keyword skips the current iteration?  Answer: continue ✅

# %% [markdown]
# 9. Which keyword exits a loop?  Answer: break ✅

# %% [markdown]
# 10. Which symbol starts a comment? Answer: #

# %% [markdown]
# 11. Which operator checks equality? Answer : ==

# %% [markdown]
# 12. Which function converts a string into an integer? Answer : int

# %% [markdown]
# 13. Output?

# %%
print(bool(""))
# Out:
# False

# %% [markdown]
# 14. Which method adds one element to a list? Answer :append()

# %% [markdown]
# 15. Which method adds multiple elements? Answer:extend()

# %% [markdown]
# 16. Which method removes the last element? Answer:pop()

# %% [markdown]
# 17. Which keyword is used for exception handling? Answer: try

# %% [markdown]
# 18. Which block always executes? Answer: finally

# %% [markdown]
# 19. Which module generates random numbers? Answer : random

# %% [markdown]
# 20. Output?

# %%
print(type(5))
# Out:
# <class 'int'>

# %% [markdown]
# 21. Which function sorts a list without changing the original?  Answer: sorted()

# %% [markdown]
# 22. Which method changes the original list ? Answer:sort()

# %% [markdown]
# 23. What is the output?

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# 24. Which keyword creates a class? Answer:class

# %% [markdown]
# 25. Which method is called automatically when an object is created?  Answer: init()

# %% [markdown]
# 26. What is inheritance? Answer: One class acquiring properties of another class ✅

# %% [markdown]
# 27. What does input() return?  Answer: string

# %% [markdown]
# 28. What is a lambda function?  Answer: Anonymous function ✅

# %% [markdown]
# 29. What is list comprehension? Answer : Loop shortcut for creating lists ✅

# %%
numbers = [x*x for x in range(5)]
print(numbers)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# 30. Which collection stores unique values?  Answer
