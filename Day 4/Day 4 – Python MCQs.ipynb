# %%
# ✅ 1. What is a Tuple? ✅ Answer- Immutable collection
# A tuple cannot be changed after it is created.

# %%
t = (10, 20, 30)
print(t)
# Out:
# (10, 20, 30)

# %%
# ✅ 2. Are tuples mutable? ✅ Answer: No

# %%
t = (1, 2, 3)

# t[0] = 10 ❌ Error

# %%
# ✅ 3. Which symbol is used to create a tuple? ✅ Answer: ()

# %%
# ✅ 4. Which method adds an element to a set?  ✅ Answer: add()

# %%
numbers = {1, 2, 3}

numbers.add(4)

print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
# ✅ 5. Which method removes an element from a set?  ✅ Answer: remove()

# %%
numbers = {1, 2, 3}

numbers.remove(2)

print(numbers)
# Out:
# {1, 3}

# %%
# ✅ 6. What does discard() do?  ✅ Answer: Removes an element without raising an error if it doesn't exist

# %%
numbers = {1, 2, 3}

numbers.discard(5)

print(numbers)
# Out:
# {1, 2, 3}

# %%
# ✅ 7. Difference between remove() and discard()? 
# ✅ Answer:remove() raises an error if the element is missing; discard() does not

# %%
numbers = {1, 2, 3}

numbers.remove(5)     # ❌ KeyError
numbers.discard(5)    # ✅ No error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 numbers = {1, 2, 3}
# ----> 3 numbers.remove(5)     # ❌ KeyError
#       4 numbers.discard(5)    # ✅ No error
#
# KeyError: 5

# %%
# ✅ 8. Which function opens a file? ✅ Answer:  open()

# %%
# file = open("test.txt", "r")

# %%
# ✅ 9. Which file mode is used for reading? ✅ Answer. r

# %%
# file = open("test.txt", "r")

# %%
# ✅ 10. Which file mode is used for appending?  ✅ Answer: a

# %%
# file = open("test.txt", "a")

# %%
# ✅ 11. What does read() return?  ✅ Answer: Whole file content

# %%
# file = open("test.txt", "r")

# print(file.read())

# %%
# ✅ 12. What does readline() return?  ✅ Answer: One line

# %%
# file = open("test.txt", "r")

# print(file.readline())

# %%
# ✅ 13. What does readlines() return?  ✅ Answer: List of all lines

# %%
# file = open("test.txt", "r")

# print(file.readlines())

# %%
# ✅ 14. Which keyword is used to handle exceptions?  ✅ Answer: try

# %%
# try:
#     print(10 / 0)
# except ZeroDivisionError:
#     print("Cannot divide by zero")

# %%
# ✅ 15. Which block always executes?  ✅ Answer: finally

# %%
# try:
#     print("Try Block")
# finally:
#     print("Always Executes")

# %%
# ✅ 16. Which keyword raises an exception manually? ✅ Answer: raise

# %%
age = -5

if age < 0:
    raise ValueError("Age cannot be negative")

# The raise keyword is used to create and throw an exception manually.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       1 age = -5
#       3 if age < 0:
# ----> 4     raise ValueError("Age cannot be negative")
#       6 # The raise keyword is used to create and throw an exception manually.
#
# ValueError: Age cannot be negative

# %%
# ✅ 17. Which module is used to work with dates and time? ✅ Answer: datetime

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-07-30 14:26:20.031460

# %%
# ✅ 18. Which function returns today's date?  ✅ Answer: date.today()

# %%
from datetime import date

print(date.today())
# Out:
# 2026-07-30

# %%
# ✅ 19. Which module is used to generate random numbers? ✅ Answer: random

# %%
import random

print(random.randint(1, 10))
# Out:
# 10

# %%
# ✅ 20. What does random.randint(1, 10) return?
# ✅ Answer: A random integer between 1 and 10 (inclusive)

# %%
# ✅ 21. What is a module?  ✅ Answer: A file containing Python code

# %%
# ✅ 22. What is a package?  ✅ Answer: A collection of related modules

# %%
# ✅ 23. Difference between import math and from math import sqrt?
# ✅ Answer:import math imports the whole module, while from math import sqrt imports only the sqrt function

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
from math import sqrt

print(sqrt(25))
# Out:
# 5.0

# %%
# ✅ 24. Which keyword creates an alias during import? ✅ Answer: as

# %%
import numpy as np

# %%
# ✅ 25. What is __name__ in Python?  ✅ Answer: A special variable that stores the module's name

# %%
# print(__name__)

# If the file is run directly, it prints:

# __main__

# %%
# ✅ 26. What is the output?
print(bool([]))
# Out:
# False

# %%
# ✅ 27. Which data type stores only unique values? ✅ Answer: Set

# %%
numbers = {1, 2, 2, 3}

print(numbers)
# Out:
# {1, 2, 3}

# %%
# ✅ 28. Which keyword skips the current iteration of a loop? ✅ Answer: continue

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
# ✅ 29. Which keyword exits a loop immediately? ✅ Answer: break
