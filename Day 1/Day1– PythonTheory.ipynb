# %% [markdown]
# 1. What is Python?
#
# Answer:
# Python is a high-level, interpreted, object-oriented programming language known for its simple syntax and readability. It is widely used in web development, automation, data science, machine learning, artificial intelligence, and software development.

# %% [markdown]
# 2. Why is Python popular in Data Science?
#
# Answer:
# Python is popular because it has powerful libraries such as NumPy, Pandas, Matplotlib, Scikit-learn, TensorFlow, and PyTorch. It is easy to learn, has a large community, and supports data analysis, visualization, and machine learning.

# %% [markdown]
# 3. What are the main features of Python?
#
# Answer:
#
# 1.Easy to read and write
# 2.Interpreted language
# 3.Object-oriented
# 4.Platform independent
# 5.Open source
# 6.Large standard library
# 7.Supports multiple programming paradigms

# %% [markdown]
# 4. What are variables?
#
# Answer:
# Variables are names used to store data in memory. Their values can be changed during program execution.

# %%
name = "rohit"
print(name)
# Out:
# rohit

# %% [markdown]
# 5. What are data types in Python?
#
# Answer:
# Data types define the kind of value stored in a variable.
#
# Common data types:
#
# 1.int
# 2.float
# 3.str
# 4.bool
# 5.list
# 6.tuple
# 7.set
# 8.dict

# %% [markdown]
# 6. Explain List, Tuple, Set, and Dictionary.
#
# 1.List
#
# -Ordered
# -Mutable
# -Allows duplicates
#
# 2.Tuple
#
# -Ordered
# -Immutable
# -Allows duplicates
#
# 3.Set
#
# -Unordered
# -Mutable
# -No duplicates
#
# 4.Dictionary
#
# -Key-value pairs
# -Mutable
# -Keys are unique

# %% [markdown]
# 7. What are operators in Python?
#
# Answer:
# Operators perform operations on variables and values.
#
# Types:
#
# 1.Arithmetic (+, -, *, /)
# 2.Comparison (==, !=, >, <)
# 3.Logical (and, or, not)
# 4.Assignment (=, +=)
# 5.Membership (in, not in)
# 6.Identity (is, is not)

# %% [markdown]
# 8. Explain if, elif, and else.
#
# Answer:
# They are used for decision making.

# %%
age = 18 
if age> 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %% [markdown]
# 9. Explain for and while loops.
#
# for loop
# Used when the number of iterations is known.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# while loop ->
# Runs until a condition becomes false.

# %%
i = 1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 10. What are functions?
#
# Answer:
# Functions are reusable blocks of code that perform a specific task.

# %%
def great():
    print("Hello")

great()
# Out:
# Hello

# %% [markdown]
# 11. What are parameters and arguments?
#
# Answer:
#
# 1.Parameters are variables in the function definition.
# 2.Arguments are the values passed to the function.

# %%
def add(a,b):
    return a+b 

add(3,5)
# Here, a and b are parameters, while 2 and 3 are arguments.
# Out:
# 8

# %% [markdown]
# 12. What is recursion?
#
# Answer:
# Recursion is a technique where a function calls itself until a base condition is met.

# %%
def fact(n):
    if n ==1:
        return 1
    return n*fact(n-1)

# %%
fact(4)
# Out:
# 24

# %% [markdown]
# 13. What are modules and packages?
#
# Module: A single Python file containing functions and classes.
#
# Package: A collection of related modules.

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %% [markdown]
# 14. What is exception handling?
#
# Answer:
# Exception handling prevents a program from crashing due to runtime errors.

# %%
try:
    print(10/0)
except ZeroDivisionError:
