# %% [markdown]
# 1. What is the extension of a Python file?
# ✅ Answer: .py

# %% [markdown]
# 2. Which keyword is used to define a function?
# ✅ Answer: def

# %% [markdown]
# 3. Which of the following is a mutable data type?
# ✅ Answer:List

# %% [markdown]
# 4. Which of the following is immutable?
# ✅ Answer: Tuple

# %% [markdown]
# 5. What does len("Python") return?
# ✅ Answer: 6

# %% [markdown]
# 6. Which operator is used for exponentiation?
# ✅ Answer: **

# %% [markdown]
# 7. What is the difference between = and ==?
# ✅ Answer: = assigns values, == compares values

# %% [markdown]
# 8. Which loop is used when the number of iterations is known?
#    ✅ Answer: for

# %% [markdown]
# 9. Which function takes user input?
#     ✅ Answer: input()

# %% [markdown]
# 10. Which data structure stores key-value pairs?
# ✅ Answer: Dictionary

# %% [markdown]
# 11. Which keyword exits a loop?
# ✅ Answer: break

# %% [markdown]
# 12. Which keyword skips the current iteration?
# ✅ Answer:  continue

# %% [markdown]
# 13. Which keyword is used to define a class?
# ✅ Answer: class

# %% [markdown]
# 14. What is the output of 5 // 2?
#     ✅ Answer: 2

# %% [markdown]
# 15. What is the output of 5 % 2?
#     ✅ Answer:  1

# %% [markdown]
# 16. Which function converts a string to an integer?
#     ✅ Answer:  int()

# %% [markdown]
# 17. Which function converts an integer to a string?
#     ✅ Answer:  str()

# %% [markdown]
# 18. Which operator checks membership?
#     ✅ Answer: in

# %% [markdown]
# 19. Which keyword is used for exception handling?
#     ✅ Answer: try

# %% [markdown]
# 20. Which block always executes?
#     ✅ Answer:  finally

# %% [markdown]
# 21. Which method adds one element to a list?
# ✅ Answer: append()

# %% [markdown]
# 22. Which method removes and returns an element?
#     ✅ Answer: pop()

# %% [markdown]
# 23. Which collection does NOT allow duplicate values?
#     ✅ Answer:  Set

# %% [markdown]
# 24. Which keyword creates an anonymous function?
#     ✅ Answer: lambda

# %% [markdown]
# 25. Which symbol starts a comment in Python?
# ✅ Answer:  #

# %% [markdown]
# 26. Which of these is a Boolean value?
#     ✅ Answer: True

# %% [markdown]
# 27. Which function displays output on the screen?
#     ✅ Answer: print()

# %% [markdown]
# 28. Which library is mainly used for numerical computing?
