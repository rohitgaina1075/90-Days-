# %%
# ✅ 1. Handle ZeroDivisionError
try:
    num = 10/0
    print(num)
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# ✅ 2. Handle ValueError
try:
    age = int(input("Enter your age: "))
    print(age)
except ValueError:
    print("Plase Enter a vaild integer: ")

# int("abc") is invalid, so Python raises a ValueError.
# Out:
# Enter your age:  gg
# Plase Enter a vaild integer:

# %%
# ✅ 3. Handle IndexError
n = [10,20,30,40,50]

try:
    print(n[8])
except IndexError:
    print("Index out of range")
# Out:
# Index out of range

# %%
# ✅ 4. Handle KeyError
student = {
    "name": "Rohit"
}

try:
    print(student["age"])

except KeyError:
    print("Key not found.")
# Out:
# Key not found.

# %%
# ✅ 5. Handle TypeError
try:
    result = "10"+10
    print(result)
except TypeError:
    print("Cannot add string and integer.")

# Python doesn't allow adding a string and an integer directly.
# Out:
# Cannot add string and integer.

# %%
# ✅ 6. Handle Multiple Exceptions
try:
    n = int(input("Enter ypur number:"))
    result= 10/n

    print(result)

except ValueError:
    print("Invalid Number: ")

except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Enter ypur number: 2
# 5.0

# %%
# ✅ 7. Catch Any Exception
try:
    x = 10/0

except Exception as e:
    print(e)

# Exception is the base class for most built-in exceptions.
# Out:
# division by zero

# %%
# ✅ 8. Use else
try:
    n = int(input("Enter your number:"))
    print(n)

except ValueError:
    print("Invalid Input")

else:
    print("Everything excuted successfully.")

# The else block runs only if no exception occurs.
# Out:
# Enter your number: 3
# 3
# Everything excuted successfully.

# %%
# ✅ 9. Use finally
try:
    print(10/2)

except ZeroDivisionError:
    print("Error")

finally:
    print("Program Finished")

# The finally block always executes, whether an exception occurs or not.
# Out:
# 5.0
# Program Finished

# %%
# ✅ 10. try, except, else, and finally Together
try:
    n = int(input("Enter your Number: "))
    result = 10/n

except ValueError:
    print("Invalid Input")

except ZeroDivisionError:
    print("Cannot divide by zero")

else:
    print("Answer :",result)

finally:
    print("Thank You")
# Out:
# Enter your Number:  3
# Answer : 3.3333333333333335
# Thank You

# %%
# ✅ 11. Raise an Exception
age = int(input("Enter Age: "))

if age < 18:
    raise Exception("You are not eligible to vote.")

print("You can vote.")

# raise is used to create an exception manually.
# If age < 18, the program stops and raises the exception.
# Out:
# Enter Age:  22
# You can vote.

# %%
# ✅ 12. Raise ValueError
marks = int(input("Enter Marks: "))

if marks < 0 or marks > 100:
    raise ValueError("Marks should be between 0 to 100. ")

print("Valid Marks")
# Out:
# Enter Marks:  33
# Valid Marks

# %%
# ✅ 13. Custom Exception
class InvalidAgeError(Exception):
    pass

age = int(input("Enter age: "))

if age < 18:
    raise IncalidAgeError("Age must be 18 or above. ")

print("Eligible")

# You created your own exception class.
# Out:
# Enter age:  44
# Eligible

# %%
# ✅ 14. Catch Custom Exception
class InvalidAgeError(Exception):
    pass

try:
    age = int(input("Enter Age: "))

    if age < 18:
        raise InvailAgeError("Not Eligible")

    print("Eligible")

except InvalidAgeError as a:
    print(e)
# Out:
# Enter Age:  33
# Eligible

# %%
# ✅ 15. File Not Found Exception
try:
    file = open("data.txt")

except FileNotFoundError:
    print("File does not exist.")
# Out:
# File does not exist.

# %%
# ✅ 16. Handle Multiple File Errors
try:
    file = open("data.txt")

    print(file.read())

except FileNotFoundError:
    print("File Missing")

except PermissionError:
    print("Permission Denied")
# Out:
# File Missing

# %%
# ✅ 17. Nested try Block
try:
    num = int(input("Enter number: "))

    try:
        result = 10/ num
        print(result)

    except XeroDivisionError:
        print("Cannot divide by zero.")

except ValueError:
    print("Invaild Number")
# Out:
# Enter number:  100
# 0.1

# %%
# ✅ 18. Using finally with File
try:
    file = open("sample.txt","w")
    file.write("Hello")

finally:
    file.close()

print("File Closed")
# Even if an error occurs while writing, the file will still be closed.
# Out:
# File Closed

# %%
# ✅ 19. Assert Statement
age = 23

assert age >= 18
print("Valid")

# assert checks whether a condition is true.
# If false:

# assert age >= 18

# Python raises an AssertionError.
# Out:
# Valid

# %%
# ✅ 20. Assertion Example
n = -5

assert n > 0, "Number must be positive"

print("n")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 # ✅ 20. Assertion Example
#       2 n = -5
# ----> 4 assert n > 0, "Number must be positive"
#       6 print("n")
#
# AssertionError: Number must be positive

# %%
# ✅ 21. Use with open() for File Handling
with open ("data.txt","w")as file:
    file.write("Hello Python")

print("File saved")
# with automatically file को close कर देता है।
# Out:
# File saved

# %%
# ✅ 22. Read File Safely
try:
    with open("data.txt","r")as file:
        data = file.read()
        print(data)

except FileNotFoundError:
    print("File Not found")
# Out:
# Hello Python

# %%
# ✅ 23. Handle Invalid Integer Input
while True:

    try:
        n = int(input("Enter a number: "))
        print("Number:",n)
        break

    except ValueError:
        print("Please enter a vaild number.")

# यह pattern user input validation में बहुत useful है।
# Out:
# Enter a number:  sd
# Please enter a vaild number.
# Enter a number:  55
# Number: 55

# %%
# ✅ 24. Create a Safe Division Function
def divide(a,b):

    try:
        return a / b

    except ZeroDivisionError:
        return "Cannot Divide by Zero"

print(divide(10,2))
print(divide(10,0))
# Out:
# 5.0
# Cannot Divide by Zero

# %%
# ✅ 25. Catch Exception Object
try:
    n = int("abc")

except ValueError as e:
    print("Error:",e)

# as e exception की information को variable e में store करता है।
# Out:
# Error: invalid literal for int() with base 10: 'abc'

# %%
# ✅ 26. Use else with File Handling
try:
    with open("data.txt", "r") as file:
        data = file.read()

except FileNotFoundError:
    print("File not found")

else:
    print("File content:")
    print(data)

# try     → risky code
# except  → error handling
# else    → no error होने पर
# finally → हमेशा
# Out:
# File content:
# Hello Python

# %%
# ✅ 27. Exception in Function
def calculate():

    try:
        x = 10/0
        return x

    except ZeroDivisionError:
        return "Cannot divide by zero"

result = calculate()
print(result)
# Out:
# Cannot divide by zero

# %%
# ✅ 28. Re-raise an Exception
def divide(a,b):

    try:
        return a/ b

    except ZeroDivisionError:
        print("Error occured")
        raise

try:
    divide(10,0)

except ZeroDivisionError:
    print("Handled in main Program")

# raise बिना argument के current exception को दोबारा ऊपर भेज सकता है।
# Out:
# Error occured
# Handled in main Program

# %%
# ✅ 29. Custom Exception with Data
class InsufficientBalanceError(Exception):
    pass

balance = 1000
withdraw = 1500

try:

    if withdraw > balance:
        raise InsufficientBalanceError("Insufficient balance")

    balance -=withdraw

except InsufficientBalanceError as e:
    print(e)
# Out:
# Insufficient balance

# %%
# ✅ 30. Multiple Exceptions in One except
try :
    n = int(input("Enter number: "))
    result = 10 / n 

except (ValueError,ZeroDivisionError):
    print("Invaild input")

# यहाँ एक ही except दो अलग exceptions handle कर रहा है।
# Out:
# Enter number:  2

# %%
# ✅ 31. Exception Hierarchy
try:
    n = [10,20]
    print(n[5])

except LookupError:
    print("Lookup error occured")

# IndexError LookupError का subclass है।

# Exception
#    ↓
# LookupError
#    ↓
# IndexError
# Out:
# Lookup error occured

# %%
# ✅ 32. Logging Errors
# Python में errors को record करने के लिए logging module use कर सकते हैं।
import logging 

logging.basicConfig(level=logging.ERROR)

try:
    result = 10/0

except ZeroDivisionError:
    logging.error("Division by Zero occurred")

# Production applications में errors को track करने के लिए logging बहुत important है।
# Out:
# ERROR:root:Division by Zero occurred

# %%
# ✅ 33. Create a Validation Function
def chack_age(age):

    if age < 0:
        raise ValueError("age cannot be negative")

    if age< 18:
        return "Minor"

    return "Adult"

try:

    age = int(input("Enter age: "))

    print(chack_age(age))

except ValueError as e:
    print("Error:",e)
# Out:
# Enter age:  33
# Adult

# %%
# ✅ 34. Bank Withdrawal Exception
# यह आपके Day 9 project से directly related है.
class InsufficientBalanceError(Exception):
    pass

balance = 5000

try:

    amount = float(input("Enter withdrawal amount: "))

    if amount <= 0:
        raise ValueError("amount must be positive")

    if amount > balance:
        raise InsufficientBalanceError(
            "Insufficient balance"
        )

    balance -=amount

    print("Withdrawal successful")
    print("Remaining balance:",balance)

except ValueError as e:
    print("Invaild amount:",e)

except InsufficientBalanceError as e:
    print("Transaction failed:",e)
# Out:
# Enter withdrawal amount:  300
# Withdrawal successful
# Remaining balance: 4700.0

# %%
# ✅ 35. Complete Exception Handling Example
class InvalidNumberError(Exception):
    pass


try:

    number = int(input("Enter a positive number: "))

    if number <= 0:
        raise InvalidNumberError(
            "Number must be greater than zero"
        )

except ValueError:
    print("Please enter a valid integer.")

except InvalidNumberError as e:
    print(e)

else:
    print("Valid number:", number)

finally:
    print("Program completed.")
# Out:
# Enter a positive number:  33
# Valid number: 33
# Program completed.
