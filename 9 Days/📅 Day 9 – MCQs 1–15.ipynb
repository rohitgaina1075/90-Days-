# %%
# ✅ 1. Which keyword is used to handle exceptions?
# ✅ Answer: B. except

# %%
# ✅ 2. Which block contains code that may cause an exception?
# ✅ Answer: C. try

# %%
# ✅ 3. Which exception occurs when dividing by zero?
# ✅ Answer: C. ZeroDivisionError

# %%
# ✅ 4. What exception does int("abc") raise?
# ✅ Answer: B. ValueError

# %%
# ✅ 5. Which exception occurs when accessing an invalid list index?
# ✅ Answer: A. IndexError

# %%
# ✅ 6. Which exception occurs when a dictionary key doesn't exist?
# ✅ Answer: B. KeyError

# %%
# ✅ 7. Which block executes when no exception occurs?
# ✅ Answer: C. else

# %%
# ✅ 8. Which block normally executes whether an exception occurs or not?
# ✅ Answer: D. finally

# %%
# ✅ 9. Which keyword manually raises an exception?
# ✅ Answer: C. raise

# %%
# ✅ 10. Which class is commonly used as the base for custom exceptions?
# ✅ Answer: B. Exception

# %%
# ✅ 11. What does as e do?
# ✅ Answer: B. Stores the exception object in e

# %%
# ✅ 12. What happens if an exception isn't handled?
# ✅ Answer: C. Program terminates and displays an error traceback

# %%
# ✅ 13. Which statement is useful for automatic file cleanup?
# ✅ Answer: B. with

# %%
# ✅ 14. What does assert raise when its condition is false?
# ✅ Answer: C. AssertionError

# %%
# ✅ 15. Which module is commonly used for application logging?
# ✅ Answer: C. logging

# %%
# ✅ 16. Which exception occurs when you try to open a file that doesn't exist?
# ✅ Answer: B. FileNotFoundError

# %%
# ✅ 17. What exception occurs when you perform an invalid operation between incompatible types?
# ✅ Answer: B. TypeError

# %%
# ✅ 18. What does this code print?
# ✅ Answer: C. 5.0 और Success

# %%
# ✅ 19. What happens here?
# ✅ Answer: C. Done और फिर ZeroDivisionError

# finally execute होता है, लेकिन exception handle नहीं हुआ, इसलिए error बाद में propagate होगा।

# %%
# ✅ 20. Which is the correct order?
# ✅ Answer: B. try → except → else → finally

# %%
# ✅ 21. What does raise do?
# ✅ Answer: B. Manually raises an exception

# %%
# # ✅ 22. Which is a valid custom exception?
# class MyError(Exception):
#     pass

# Custom exceptions normally inherit from Exception.

# %%
# ✅ 23. What does this code print?
# ✅ Answer: B. Valid

# "10" successfully converts to integer.

# %%
# # ✅ 24. What does finally mainly help with?
# ✅ Answer: B. Cleanup

# For example:

# Closing files
# Releasing resources
# Closing database connections

# %%
# ✅ 25. Which statement is TRUE about finally?
# ✅ Answer: It normally executes regardless of whether an exception occurs

# finally is designed to execute whether an exception occurs or not.

# %%
✅ 26. What does this code produce?
✅ Answer: C. Wrong index

Index 10 doesn't exist.
