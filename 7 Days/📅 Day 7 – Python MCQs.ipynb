# %%
# ✅ 1. Which module provides mathematical functions?
# ✅ Answer: math

# %%
# ✅ 2. Which function returns the square root?
# ✅ Answer: math.sqrt()

# %%
# ✅ 3. Which constant represents π?
# ✅ Answer: math.pi

# %%
# ✅ 4. Which module generates random numbers?
# ✅ Answer: random

# %%
# ✅ 5. What does random.randint(1,5) return?
# ✅ Answer: 1 to 5

# randint(a, b) includes both a and b

# %%
# ✅ 6. Which function selects a random element from a list?
# ✅ Answer: random.choice()

# %%
# ✅ 7. Which function shuffles a list?
# ✅ Answer: random.shuffle()

# %%
# ✅ 8. Which module handles date and time?
# ✅ Answer: datetime

# %%
# ✅ 9. Which function returns the current date and time?
# ✅ Answer:: datetime.now()

# %%
# ✅ 10. Which function returns only today's date?
# ✅ Answer: date.today()

# %%
# ✅ 11. Which module is used for operating system operations?
# ✅ Answer: os

# %%
# ✅ 12. Which function returns the current working directory?
# ✅ Answer: os.getcwd()

# %%
# ✅ 13. Which function lists files in a directory?
# ✅ Answer: os.listdir()

# %%
# ✅ 14. Which function checks whether a file exists?
# ✅ Answer: os.path.exists()

# %%
# ✅ 15. Which module provides access to command-line arguments?
# ✅ Answer: sys

# %%
# ✅ 16. Which module is used to work with JSON data?
# ✅ Answer: json

# %%
# ✅ 17. Which function converts a Python object into a JSON string?
# ✅ Answer: json.dumps()

# %%
# ✅ 18. Which function converts a JSON string into a Python object?
# ✅ Answer: json.loads()

# %%
# ✅ 19. Which function writes JSON data to a file?
# ✅ Answer: json.dump()

# %%
# ✅ 20. Which function reads JSON data from a file?
# ✅ Answer: json.load()

# %%
# ✅ 21. Which module is used to work with CSV files?
# ✅ Answer: csv

# %%
# ✅ 22. Which function writes one row to a CSV file?
# ✅ Answer: writerow()

# %%
# ✅ 23. Which function writes multiple rows to a CSV file?
# ✅ Answer: writerows()

# %%
# ✅ 24. Which collection counts the frequency of elements?
# ✅ Answer: Counter

# %%
# ✅ 25. Which collection automatically provides default values for missing keys?
# ✅ Answer: defaultdict

# %%
# ✅ 26. Which collection is efficient for adding and removing elements from both ends?
# ✅ Answer: deque

# %%
# ✅ 27. Which function copies a file?
# ✅ Answer: shutil.copy()

# %%
# ✅ 28. Which function moves a file?
✅ Answer shutil.move()
