# %%
# ✅ 1. What is a Module in Python?
# Answer

# A module is a Python file (.py) that contains functions, classes, and variables. Modules help organize code and promote reuse.

# Example

# Suppose calculator.py contains:

# %%
def add(a, b):
    return a + b

# %%
# ✅ 2. What is a Package?
# Answer

# A package is a collection of related Python modules stored in a directory.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       1 # Use it in another file:
#       3 import math
# ----> 5 print(math.add(10, 20))
#
# AttributeError: module 'math' has no attribute 'add'

# %%
# Difference
# Module	                          Package
# Single .py file	                  Folder containing modules
# Contains code	                  Organizes multiple modules

# %%
# ✅ 3. Difference Between import module and from module import name
#1. Using import
import math

print(math.sqrt(25))

# 2.Using from
from math import sqrt

print(sqrt(25))
# Out:
# 5.0
# 5.0

# %%
# Difference
# import math                	       from math import sqrt
# Use math.sqrt()	                   Use sqrt() directly
# Imports whole module	           Imports only the specified object

# %%
# ✅ 4. What is the math Module?
# Answer

# The math module provides mathematical functions and constants.

# %%
import math

math.sqrt(25)
math.pow(2, 5)
math.ceil(2.3)
math.floor(2.9)
math.pi
# Out:
# 3.141592653589793

# %%
# ✅ 5. What is the random Module?
# Answer

# The random module is used to generate random numbers or make random selections.

# %%
import random

random.randint(1, 10)
random.choice(["Apple", "Banana", "Mango"])
random.shuffle([1, 2, 3])

# %%
# ✅ 6. Difference Between randint() and choice()
# randint()	                                   choice()
# Returns a random integer in a range	           Returns a random element from a sequence

# %%
random.randint(1, 10)
random.choice(["A", "B", "C"])
# Out:
# 'B'

# %%
# ✅ 7. What is the datetime Module?
# Answer

# The datetime module helps work with dates and times.

# %%
from datetime import datetime

print(datetime.now())

# Common uses:

# Current date
# Current time
# Date calculations
# Formatting dates
# Out:
# 2026-08-02 14:15:26.530799

# %%
# ✅ 8. Difference Between date.today() and datetime.now()
# date.today()	                       datetime.now()
# Returns only the date	                Returns date and current time

# %%
from datetime import date, datetime

print(date.today())
print(datetime.now())
# Out:
# 2026-08-02
# 2026-08-02 14:15:58.272106

# %%
# ✅ 9. What is the os Module?
# Answer

# The os module lets Python interact with the operating system.

# %%
import os

# os.getcwd()
# os.listdir()
# os.mkdir("Folder")
# os.remove("file.txt")

# %%
# ✅ 10. What is the sys Module?
# Answer

# The sys module provides access to Python interpreter settings and command-line arguments.

# %%
# import sys

# print(sys.version)
# print(sys.argv)

# %%
# ✅ 11. What is JSON?
# Answer

# JSON (JavaScript Object Notation) is a lightweight format for storing and exchanging data.

# %%
{
  "name": "Rohit",
  "age": 21
}
# Python uses the json module to work with JSON data.
# Out:
# {'name': 'Rohit', 'age': 21}

# %%
# # ✅ 12. Difference Between dump(), dumps(), load(), and loads()
# Function	                 Purpose
# dump()	                     Write Python object to a JSON file
# dumps()	                     Convert Python object to a JSON string
# load()	                     Read JSON from a file
# loads()	                     Convert a JSON string to a Python object

# %%
# ✅ 13. What is CSV?
# Answer

# CSV (Comma-Separated Values) is a file format used to store tabular data.

# %%
# Name,Age
# Rohit,21
# Amit,22

# Python uses the built-in csv module to read and write CSV files.

# %%
# ✅ 14. What are Counter, defaultdict, and deque?

# These are classes from the collections module.
# Counter

# Counts the frequency of elements.

# %%
from collections import Counter

Counter("banana")
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})

# %%
# defaultdict

# Provides a default value for missing keys.

# %%
from collections import defaultdict

d = defaultdict(int)

# %%
# deque

# A double-ended queue that supports fast insertion and deletion from both ends.

# %%
from collections import deque

dq = deque([1, 2, 3])

# %%
# ✅ 15. What is pathlib?
# Answer

# pathlib is the modern, object-oriented way to work with file and directory paths.

# %%
from pathlib import Path

file = Path("students.csv")

print(file.exists())
# Out:
# False
