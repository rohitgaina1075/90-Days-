# %%
import os

class ContactBook:

    File_Name = "contacts.txt"

    def add_contact(self):

        name = input("Enter Name: ").strip()
        phone = input("Enter Phone: ").strip()
        email = input("Enter Email: ")..strip()

        with open(self.File_Name,"a") as file:
            file.write(f"{name},{phone},{email}\n")

        print("✅ Contact Added Successfully!")

    def view_contects(self):

        if not os.path.exists(self.File_Name):
            print("No contacts found.")
            return

        with open(self.File_Name,"r") as file:
            contacts = file.readlines()

        if not contacts:
            print("Contact list is empty.")
            return

        print("\n---------------------------------------------")
        print("Name\t\tPhone\t\tEmail")
        print("---------------------------------------------")

        for contact in contacts:
            name,phone,email = contact.strip().spilt(",")
            print(f"{name}\t{phone}\t{email}")

        def search_contact(self):

            searrch = input("Enter Name: ").lower()

            if not os.path.exits(self.File_Name):
                print("No contacts found.")
                return

            found = False

            with open(self.File_Name,"r") as file:

                for contact in file:

                    name,phone email = contact.strip().split(",")

                    if name.lower() == search:

                        print("\n Contact Found")
                        print("Name:",name)
                        print("Phone:",phone)
                        print("Email:",email)

                        found = True

                if not found:
                    print("Contact Not Found")

            def update_contact(self):

                search = input("Enter Contact Name: ").lower()

                if not os.path.exits(self.File_Name):
                    print("No contacts found.")
                    return

                updated = []
                found = False

                with open(self.File_Name,"r") as file:

                    for contact in file:

                        name,phone,email = contact.strip().spilt(",")

                        if name.lower() == search:

                            print("Leave blank to keep current value.")

                            new_name = input(f"New Name ({name}):").strip() or name
                            new_phone = input(f"New Phone ({phone}):").strip() or phone
                            new_email = input(f"New Email ({email}):").strip() or email

                            update.append(f"{new_name},{new_phone},{new_email}\n")
                            found = True

                        else:
                            update.append(contact)

                    with open(self.File_Name,"w") as file:
                        file.writelines(updated)

                    if found:
                        print("✅ Contact Updated Successfully!")
                    else:
                        print("Contact Not found")

                def delete_contact(self):

                    search = input("Enter Contact Name: ").lower()

                    if not os.path.exists(self.File_Name):
                        print("No contacts found.")
                        return

                    updated = []
                    found = False

                    with open (self.File_Name,"r")as file:

                        for contact in file:

                            name,phone, email = contact.strip().split(",")

                            if name.lower() == search :
                                found = True 
                            else:
                                updated.append(contact)

                        with open(self.File_Name,"w") as file:
                            file.writelines(updated)

                        if found:
                            print("✅ Contact Deleted Successfully!")
                        else:
                            print("Contact Not Found")




                def count_contacts(self):

                     if not os.path.exists(self.File_Name):
                         print("Total contacts: 0")
                         return
                    with open(self.File_Name,"r") as file:
                        contacts = file.readlines()

                    print("Total contacts:",len(contacts))

book = ContactBook()

while True:

    print("\n=============================")
    print("      CONTACT BOOK")
    print("=============================")
    print("1. Add Contact")
    print("2. View Contacts")
    print("3. Search Contact")
    print("4. Update Contact")
    print("5. Delete Contact")
    print("6. Count Contacts")
    print("7. Exit")


    choice = input("Enter Choice: ")

    if choice =="1":
        book.add_contact()

    elif choice =="2":
        book.view_contact()

    elif choice =="3":
        book.search_contact()

     elif choice == "4":
        book.update_contact()

    elif choice == "5":
        book.delete_contact()

    elif choice == "6":
        book.count_contacts()

    elif choice == "7":
        print("Thank You!")
        break

    else:
        print("Invalid Choice!")
# Out:
#   File <string>:144
#     with open(self.File_Name,"r") as file:
#                                           ^
# IndentationError: unindent does not match any outer indentation level
