# %%
# ✅ 1. What does *args represent?
# ✅ Answer: Tuple

# %%
def add(*args):
    print(type(args))

add(1,2,3)
# Out:
# <class 'tuple'>

# %%
# ✅ 2. What does **kwargs represent?
# ✅ Answer: Dictionary

# %%
def show(**kwargs):
    print(kwargs)

show(name="Rohit", age=21)
# Out:
# {'name': 'Rohit', 'age': 21}

# %%
# ✅ 3. Which keyword is used to create an anonymous function?
# ✅ Answer: lambda

# %%
# ✅ 4. What is the output?
square = lambda x: x*x

print(square(4))
# Out:
# 16

# %%
# ✅ 5. Which function applies another function to every element?
# ✅ Answer: map()

# %%
# ✅ 6. Which function removes unwanted elements?
# ✅ Answer:filter()

# %%
# ✅ 7. Which module contains reduce()?
# ✅ Answer: functools

# %%
# ✅ 8. What does reduce() return?
# ✅ Answer: Single Value

# %%
# ✅ 9. Which keyword is used in generators?
# ✅ Answer: yield

# %%
# ✅ 10. What is the main advantage of generators?
# ✅ Answer: Less memory usage

# %%
# ✅ 11. Which function creates an iterator?
# ✅ Answer: iter()

# %%
# ✅ 12. Which function gets the next element from an iterator?
# ✅ Answer: next()

# %%
# ✅ 13. Which exception is raised when an iterator finishes?
# ✅ Answer: StopIteration

# %%
# ✅ 14. What is recursion?
# ✅ Answer: Function calling itself

# %%
# ✅ 15. What is the base case in recursion?
# ✅ Answer: Condition that stops recursion

# %%
# ✅ 16. Which keyword is used to handle exceptions?
# ✅ Answer: except

# %%
# ✅ 17. Which block always executes whether an exception occurs or not?
# ✅ Answer: finally

# %%
# ✅ 18. Which keyword is used to raise an exception manually?
# ✅ Answer: raise

# %%
# ✅ 19. Which statement creates a custom exception?
class MyError(Exception):
    pass

# %%
# ✅ 20. Which statement automatically closes a file?
# ✅ Answer: with

# %%
# ✅ 21. What does enumerate() return?
# ✅ Answer:: Index and value

# %%
names = ["A", "B"]

for index, value in enumerate(names):
    print(index, value)
# Out:
# 0 A
# 1 B

# %%
# ✅ 22. What does zip() do?
# ✅ Answer: Combines iterables

# %%
# ✅ 23. Which comprehension creates a dictionary?
{x: x*x for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
# ✅ 24. Which comprehension removes duplicate values?
# ✅ Answer: Set comprehension

# %%
# ✅ 25. What is the output?
list(map(lambda x: x*2, [1,2,3]))
# Out:
# [2, 4, 6]

# %%
# ✅ 26. What is the output?
list(filter(lambda x:x>2,[1,2,3,4]))
# Out:
# [3, 4]

# %%
# ✅ 27. What is the output?
from functools import reduce

print(reduce(lambda x,y:x+y,[1,2,3]))
# Out:
# 6

# %%
# ✅ 28. Which function returns the length of a list?
# ✅ Answer: len()

# %%
# ✅ 29. Which function returns the data type of an object?
# ✅ Answer:: type()
